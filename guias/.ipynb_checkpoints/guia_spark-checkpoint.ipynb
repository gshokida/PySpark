# %%
import pyspark

try: 
    type(sc)
except NameError:
    sc = pyspark.SparkContext('local[*]')    
    
type(sc)
# Out:
# pyspark.context.SparkContext

# %%
import os
os.path.normpath("file:\\C:\\Users\\german.shokida\\Documents\\GitHub\\PySpark\\guias\\Archivo.txt")

#inputfile = sc.textFile(os.path.normpath("file://C:\\Users\\german.shokida\\Documents\\GitHub\\PySpark\\guias\\Archivo.txt"))
# Out:
# 'file:\\C:\\Users\\german.shokida\\Documents\\GitHub\\PySpark\\guias\\Archivo.txt'

# %%
rdd = sc.textFile("Archivo.txt")

# %%
rdd.take(3)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-40-a192b5d32554> in <module>()
# ----> 1 rdd.take(3)
#
# C:\Users\german.shokida\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyspark\rdd.py in take(self, num)
#    1341
#    1342             p = range(partsScanned, min(partsScanned + numPartsToTry, totalParts))
# -> 1343             res = self.context.runJob(self, takeUpToNumLeft, p)
#    1344
#    1345             items += res
#
# C:\Users\german.shokida\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyspark\context.py in runJob(self, rdd, partitionFunc, partitions, allowLocal)
#     990         # SparkContext#runJob.
#     991         mappedRDD = rdd.mapPartitions(partitionFunc)
# --> 992         port = self._jvm.PythonRDD.runJob(self._jsc.sc(), mappedRDD._jrdd, partitions)
# ...

# %%
print(rdd.flatMap(lambda x: x).collect())
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-12-02d42ec3da43> in <module>()
# ----> 1 print(rdd.flatMap(lambda x: x).collect())
#
# C:\Users\german.shokida\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyspark\rdd.py in collect(self)
#     807         """
#     808         with SCCallSiteSync(self.context) as css:
# --> 809             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     810         return list(_load_from_socket(port, self._jrdd_deserializer))
#     811
#
# C:\Users\german.shokida\AppData\Local\Continuum\Anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1158         answer = self.gateway_client.send_command(command)
#    1159         return_value = get_return_value(
# -> 1160             answer, self.gateway_client, self.target_id, self.name)
#    1161
# ...

# %%
rdd.take(3)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-31-a192b5d32554> in <module>()
# ----> 1 rdd.take(3)
#
# C:\Users\german.shokida\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyspark\rdd.py in take(self, num)
#    1311         """
#    1312         items = []
# -> 1313         totalParts = self.getNumPartitions()
#    1314         partsScanned = 0
#    1315
#
# C:\Users\german.shokida\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyspark\rdd.py in getNumPartitions(self)
#     383         2
#     384         """
# --> 385         return self._jrdd.partitions().size()
#     386
#     387     def filter(self, f):
#
# C:\Users\german.shokida\AppData\Local\Continuum\Anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1158         answer = self.gateway_client.send_command(command)
# ...

# %%
sc.textFile("Archivo.txt").flatMap(lambda a: a.split()).map(lambda a: (a, 1)).take(10)
#reduceByKey(lambda a, b: a+b).takeOrdered(3, key = lambda x: -x[1])
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-8-ad4b89e9bed3> in <module>()
# ----> 1 sc.textFile("Archivo.txt").flatMap(lambda a: a.split()).map(lambda a: (a, 1)).take(10)
#       2 #reduceByKey(lambda a, b: a+b).takeOrdered(3, key = lambda x: -x[1])
#
# C:\Users\german.shokida\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyspark\rdd.py in take(self, num)
#    1341
#    1342             p = range(partsScanned, min(partsScanned + numPartsToTry, totalParts))
# -> 1343             res = self.context.runJob(self, takeUpToNumLeft, p)
#    1344
#    1345             items += res
#
# C:\Users\german.shokida\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyspark\context.py in runJob(self, rdd, partitionFunc, partitions, allowLocal)
#     990         # SparkContext#runJob.
#     991         mappedRDD = rdd.mapPartitions(partitionFunc)
# ...
